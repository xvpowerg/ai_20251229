# %%
print(12345)#函式
# Out:
# 12345

# %%
#整數 代號是int
a = 3
b = 2
c = 8
y  =a + b * c
print(y)
# Out:
# 19

# %%
#浮點數 float 有小數點的數
pi = 3.1415
r = 10
ans = pi * r
print(ans)
# Out:
# 31.415000000000003

# %%
#字串 str
msg = "你好啊!"
print(msg)
msg2 = '晚安!'
print(msg2)
# Out:
# 你好啊!
# 晚安!

# %%
name = "Ken"
age = 18
print(name,age)
# Out:
# Ken 18
