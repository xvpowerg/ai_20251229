# %% [markdown]
# ## 作業
#
# 設計錢包總金額為 1000 元，
#
# 如果購買商品總金額超過 1000
#
# 會引發一個金額不足的例外 OverflowError

# %%
mySum = 0
dic1 = {}
try:
    while True:
        item = input("消費項目")
        price = int(input("消費金額"))
        if mySum + price > 1000:
            raise OverflowError("已經超支了")
        dic1[item] = price
        mySum += price
except OverflowError as ex:
    print(ex)
print(dic1)
# Out:
# 消費項目 AA
# 消費金額 100
# 消費項目 BB
# 消費金額 900
# 消費項目 CC
# 消費金額 1
# 已經超支了
# {'AA': 100, 'BB': 900}

# %%
dic1 = {}
def consume():
    mySum = 0    
    while True:
        item = input("消費項目")
        price = int(input("消費金額"))
        if mySum + price > 1000:
            raise OverflowError("已經超支了")
        dic1[item] = price
        mySum += price    
try:
    consume()
except OverflowError as ex:
    print(ex)
print(dic1)
# Out:
# 消費項目 AAA
# 消費金額 900
# 消費項目 BB
# 消費金額 100
# 消費項目 CC
# 消費金額 1
# 已經超支了
# {'AAA': 900, 'BB': 100}

# %%
class Employee:
    def __init__(self,name,salary=26000):
        self.name = name
        self.salary = salary
emp1 =  Employee("Ken",56000) 
print(emp1.name)
print(emp1.salary)
print("=========")
emp2=  Employee("Vivin") 
print(emp2.name)
print(emp2.salary)
# Out:
# Ken
# 56000
# ...
# Vivin
# 26000

# %%
class Employee:
    def __init__(self,name,salary=26000):
        self.name = name
        self.salary = salary
    def printInfo(self):
        print(self.name,self.salary)
        
emp3 = Employee("Lucy",86000)
emp4 = Employee("Iris")
emp3.printInfo()
emp4.printInfo()
# Out:
# Lucy 86000
# Iris 26000

# %%
class Point:
    def __init__(self,x=0,y=0):
        self.x = x
        self.y = y
    def __str__(self):
        return f"({self.x},{self.y})"
p1 = Point(2,3)
p2 = Point(-1,2)
print(p1)
print(p2)
# Out:
# (2,3)
# (-1,2)

# %% [markdown]
# https://docs.python.org/zh-tw/3/library/operator.html
# ``` python
# __add__  +
#
# __iadd__  +=
#
# __sub__  -
#
# __isub__  -=
#
# __mul__  *
#
# __imul__  *=
#
# __truediv__   /
#
# __itruediv__   /=
#
# __floordiv__  //
#
# __ifloordiv__  //=
#
# __mod__  %
#
# __imod__  %=
#
# __pow__  **
#
# __ipow__  **=
# ```

# %%
class Point:
    def __init__(self,x=0,y=0):
        self.x = x
        self.y = y
    def __str__(self):
        return f"({self.x},{self.y})"
    def __add__(self,other):#self 是 p1 other是p2
        x = self.x + other.x
        y = self.y + other.y
        return Point(x,y)
    def __sub__(self,other):
        x = self.x - other.x
        y = self.y - other.y
        return Point(x,y)
p1 = Point(2,3)
p2 = Point(-1,2)
print(p1)
print(p2)
print(p1 + p2)
print(p1 - p2)
# Out:
# (2,3)
# (-1,2)
# (1,5)
# (3,1)

# %%
class Point:
    def __init__(self,x=0,y=0):
        self.x = x
        self.y = y
    def __str__(self):
        return f"({self.x},{self.y})"
    def __add__(self,other):#self 是 p1 other是p2
        x = self.x + other.x
        y = self.y + other.y
        return Point(x,y)
    def __sub__(self,other):
        x = self.x - other.x
        y = self.y - other.y
        return Point(x,y)
    def __len__(self):    
        self_len =  (self.x ** 2) + (self.y ** 2)
        return self_len
p1 = Point(2,3)
p2 = Point(-1,2)
print(len(p1))
print(len(p2))
# Out:
# 13
# 5

# %%
list2 = [1,2,3,4,5]
print(len(list2))
# Out:
# 5

# %%
class Point:
    def __init__(self,x=0,y=0):
        self.x = x
        self.y = y
    def __str__(self):
        return f"({self.x},{self.y})"
    def __add__(self,other):#self 是 p1 other是p2
        x = self.x + other.x
        y = self.y + other.y
        return Point(x,y)
    def __sub__(self,other):
        x = self.x - other.x
        y = self.y - other.y
        return Point(x,y)
    def __len__(self):    
        self_len =  (self.x ** 2) + (self.y ** 2)
        return self_len
    def __lt__(self,other):    
        return len(self) < len(other)
p1 = Point(2,3)
p2 = Point(1,1)
p3 = Point(4,9)
p4 = Point(5,7)

pList = [p1,p2,p3,p4]
pList.sort()
for p in pList:
    print(p)
# Out:
# (1,1)
# (2,3)
# (5,7)
# (4,9)

# %% [markdown]
# ## 目錄管理

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\xvpow\ai_20251229\ch12

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'Untitled.ipynb']

# %% [markdown]
# ## 檔案存取
#
# file object = open(file_name [, access_mode])
#
# UTF8 編碼資料還請加入另一個參數才可避免亂碼：encoding=‘utf-8'
# file object = open(file_name [, access_mode])
#
# 參數說明
#
# file_name：file_name 參數是一個字串資料，代表包含要連結的文件名稱。
#
# access_mode：access_mode 確定文件必須打開的模式，包括讀取、寫入、附加等等。稍後會列完整列表。這是可選參數，默認文件訪問模式為讀取(r)。
#
# |模式	|可做操作|若檔案不存在|是否覆蓋|
# |----|--------|-----------|-------|
# |r	|只能讀|報錯	|-|
# |r+	|可讀可寫|報錯|是|
# |w	|只能寫|建立|是|
# |w+ |可讀可寫|建立|是|
# |a　|只能寫|建立|否，追加寫|
# |a+	|可讀可寫|建立|否，追加寫|

# %%
text = """python與中文AAA
1. 我們來試試看中文儲存能力。
2. 許這個字會有編碼衝突風險。
3. 犇這個字必須是utf8編碼才有。
"""
print(text,file=open("data.txt","w",encoding="utf-8"))

# %%
text = """python與中文AAA
1. 我們來試試看中文儲存能力。
2. 許這個字會有編碼衝突風險。
3. 犇這個字必須是utf8編碼才有。
"""

file = open("data2.txt","w",encoding="utf-8")
file.write(text)
file.close()

# %% [markdown]
# ## 作業

# %%
#建立一個Student 類別 我希望可以 有兩個屬性 name score
#st1 = Student("Ken",85)
#st2 = Student("Iris",73)
#print(st1) Ken 85
#print(st2) Iris 73
#print(st1 < st2) False 比成績
